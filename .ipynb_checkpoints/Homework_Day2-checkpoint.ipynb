# %%
try:
    name = ciao
except NameError as e :
 print(f"the following is the error {e}")
# Out:
# the following is the error name 'ciao' is not defined

# %%
a = "Ciao "
b = 0
concatenate_string = a + b
print (concatenate_string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 a = "Ciao "
#       2 b = 0
# ----> 3 concatenate_string = a + b
#       4 print (concatenate_string)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def concatenate_strings (a,b):
    return a + b
    print: ("return")

print (concatenate_strings(a,b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 5
#       2     return a + b
#       3     print: ("return")
# ----> 5 print (concatenate_strings(a,b))
#
# Cell In[44], line 2, in concatenate_strings(a, b)
#       1 def concatenate_strings (a,b):
# ----> 2     return a + b
#       3     print: ("return")
#
# TypeError: can only concatenate str (not "int") to str

# %%
try: 
    concatenate_string = a + b 
except TypeError as e:
    print(f"you cannot concatenate a integrer and a string as: {e}")
# Out:
# you cannot concatenate a integrer and a string as: can only concatenate str (not "int") to str

# %%
list = [1,2,3,4,5,6,7]
print (list [10])

try: 
    list = [1,2,3,4,5,6,7]
except IndexError as e:
    print (f"you cannot print a character that is not present in the list as the list is not long enought , based on {e}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[72], line 2
#       1 list = [1,2,3,4,5,6,7]
# ----> 2 print (list [10])
#       4 try:
#       5     list = [1,2,3,4,5,6,7]
#
# IndexError: list index out of range

# %%
try: 
    list [10]
except IndexError as e:
    print (f"you cannot print a character that is not present in the list as the list is not long enought , based on {e}")
# Out:
# you cannot print a character that is not present in the list as the list is not long enought , based on list index out of range

# %%
2 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 2 / 0
#
# ZeroDivisionError: division by zero

# %%
try: 
    2 / 0
except Exception as e : 
    print (f"Be aware that here there is an error, which is the following : {e}")
# Out:
# Be aware that here there is an error, which is the following : division by zero

# %%
def calcolatrice ():
    num1 = float(input("inserisci il primo numero"))
    operatore = str(input("inserisci l'operatore"))
    num2 = float (input("inserisci il secondo numero"))
    if operatore == "+":
        risultato = num1 + num2
    elif operatore == "-":
        risultato = num1 - num2
    elif operatore == "/":
        risultato = num1 / num2
    elif operatore == "%" :
        risultato = num1 % num2 

    print(f"risultato: {risultato}")

# %%
c = input("Please enter your name to start: "),
print("Welcome " + (c) + " to the calculation")
# Out:
# Please enter your name to start:  w
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 2
#       1 c = input("Please enter your name to start: "),
# ----> 2 print("Welcome " + (c) + " to the calculation")
#
# TypeError: can only concatenate str (not "tuple") to str

# %%
print("START")
c = input("Please enter your name to start: ")
print("Welcome " + c + " to the calculation")
print("END")
# Out:
# START amrco
# Please enter your name to start:  marco
# Welcome marco to the calculation marco
# END marco
# 'marco '

# %%
def calcolatrice ():
    num1 = float(input("inserisci il primo numero"))
    operatore = str(input("inserisci l'operatore"))
    num2 = float (input("inserisci il secondo numero"))
    if operatore == "+":
        risultato = num1 + num2
    elif operatore == "-":
        risultato = num1 - num2
    elif operatore == "/":
        risultato = num1 / num2
    elif operatore == "%" :
        risultato = num1 % num2 

    print(f"risultato: {risultato}")
calcolatrice ()
# Out:
# inserisci il primo numero 1
# inserisci l'operatore -
# inserisci il secondo numero 2
# risultato: -1.0

# %%
f = "ciao"
c = "come va"
f += f
f == c
f
# Out:
# 'ciaociao'

# %%
h = "ciao"
c = "come va"
h == c
print(h)
# Out:
# ciao k
# 'k'

# %%
h = "ciao"
n = "come va"
print(h == n)
print(bool(n))
# Out:
# False
# True

# %%
a = 1 
b = 2 
c = 3 
d = 4 
e = 5 
f = 6 

a>b or b<c and f>c and e >d
# Out:
# True
