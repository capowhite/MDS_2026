# %%
s = "ciao come va ?"
s
# Out:
# 'ciao come va ?'

# %%
s1 = ' Ciao come va ?'
s1
# Out:
# ' Ciao come va ?'

# %%
s2 = ' ciao" coem va " ?'
s2
# Out:
# ' ciao" coem va " ?'

# %%
#f- string 
nome = " Alessio"
print (f"Ciao{nome}, come stai?")
# Out:
# Ciao Alessio, come stai?

# %%
nome = " Alessio"
print (f"Ciao {nome} ! \nCome stai ?")
# Out:
# Ciao  Alessio !
# Come stai ?

# %%
s3 = "today is a very good day"
s3
# Out:
# 'today is a very good day'

# %%
s3[0:2] + s3[-2:]
# Out:
# 'toay'

# %%
s4 = s3[0:2]
s5 = s3[-2:]
s4.lower() + s5.upper()
# Out:
# 'toAY'
