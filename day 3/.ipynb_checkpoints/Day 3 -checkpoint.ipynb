# %%
def greet (name) :
    name = name.upper()
    print(f"Hello {name}")

# %%
greet("alice")
# Out:
# Hello ALICE

# %%
employee = "Salim"
greet (employee)
# Out:
# Hello SALIM

# %%
employee
# Out:
# 'Salim'

# %%
def calculate_are (a,b):
 return a * b 

calculate_are (10,20)
# Out:
# 200

# %%
def introduce (name, age=25):
    return (f"Hello, my name is {name}, and i am {age}")
introduce ("alessio")
# Out:
# 'Hello, my name is alessio, and i am 25'

# %%
my_list = [1,2,3,4,5,2,4,5]
def first_and_last (l):
   return l[0],l[-1]
first_and_last(my_list)
# Out:
# (1, 5)

# %%
# !pip install numpy

# %%
# !pip install numpy==2.4.2
import numpy as np

# %%
dir(np) # per vedere quali funzioni ci sono dentro la librerua numpy
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
# ...

# %%
import sys
# !{sys.executable} -m pip install numpy
# Out:
# ...
#   Using cached numpy-2.4.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.2-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
# ...

# %%
import numpy as np

# %%
from numpy import arange # adesso posso usare arange senza dover scrivere numpy.arange()

# %%
arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
import math 
math.sqrt(16)
# Out:
# 4.0

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 2, 18, 9, 52, 24, 222844)

# %%
import datetime as dt

# %%
dt.datetime.now()
# Out:
# datetime.datetime(2026, 2, 18, 9, 54, 55, 237905)

# %%
ora  = dt.datetime.now()
ora.strftime("%d/%m/%Y %H:%M:%S") # per trasformare da formato non tanto leggibile in formato leggibile
# Out:
# '18/02/2026 09:58:08'

# %%
from random import randomint
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from random import randomint
#
# ImportError: cannot import name 'randomint' from 'random' (/opt/miniconda3/envs/myenv312/lib/python3.11/random.py)

# %%
dir (random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
from random import randint

# %%
randint(1,7)
# Out:
# 1

# %% [raw]
# random.randint(1;100)

# %% [markdown]
# # request library

# %%
# !pip install requests

# %%
import requests

# %%
url = "https://www.stats.govt.nz/assets/Uploads/Business-operations-survey/Business-operations-survey-2022/Download-data/business-operations-survey-2022-business-finance.csv"

# %%
requests.get(url) #200 is good as it measn that it read the file and have access to it and everyghing went well.
# Out:
# <Response [200]>

# %%
response = requests.get(url) 
response.text # scrivo .text della variabile per vedere cosa dice
# Out:
# 'description,industry,level,size,line_code,value\r\nType of outstanding debt: bank overdrafts,total,0,6ñ19 employees,D0201,13215\r\nType of outstanding debt: bank overdrafts,total,0,20ñ49 employees,D0201,3405\r\nType of outstanding debt: bank overdrafts,total,0,50ñ99 employees,D0201,978\r\nType of outstanding debt: bank overdrafts,total,0,100+ employees,D0201,687\r\nType of outstanding debt: bank overdrafts,"Agriculture, forestry, & fishing",1,total,D0201,1974\r\nType of outstanding debt: bank overdrafts,Agriculture,2,total,D0201,1371\r\nType of outstanding debt: bank overdrafts,Commercial fishing,2,total,D0201,24\r\nType of outstanding debt: bank overdrafts,Forestry & logging,2,total,D0201,117\r\nType of outstanding debt: bank overdrafts,"Agriculture, forestry, & fishing support services",2,total,D0201,465\r\nType of outstanding debt: bank overdrafts,Mining,1,total,D0201,30\r\nType of outstanding debt: bank overdrafts,Manufacturing,1,total,D0201,2424\r\nType of outstanding debt: ban
# ...

# %% [markdown]
# # to navigate in the file system - i use the os library

# %%
import os 
os.getcwd()
# Out:
# '/Users/alessiocapobianco/Source/MDS_2026/day 3'

# %%
os.setdwc('/Users/alessiocapobianco/Source/MDS_2026/Day2')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 os.setdwc('/Users/alessiocapobianco/Source/MDS_2026/Day2')
#
# AttributeError: module 'os' has no attribute 'setdwc'

# %% [markdown]
# # import csv file - esericizio
# CSV library

# %%
import csv

with open("my_data.csv") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['id', 'name', 'age', 'city ']
# ['1', ' alessio', ' 24', ' Novara']
# ['2', ' francesco', ' 25', ' Milano']
# ['3', ' elena', ' 26', ' Palermo ']
# ['4', ' salim', ' 28', ' Torino']
# ['5', ' Michale', ' 45', ' Perugia']
# ['6', ' Dilva', ' 56', ' Modena']

# %%
os.read(

# %%
import csv

with open("my_data.csv") as f:
    reader = csv.DictReader(f) # trasforma in un dictionary
    for row in reader:
        print(row)
# Out:
# {'id': '1', 'name': ' alessio', 'age': ' 24', 'city ': ' Novara'}
# {'id': '2', 'name': ' francesco', 'age': ' 25', 'city ': ' Milano'}
# {'id': '3', 'name': ' elena', 'age': ' 26', 'city ': ' Palermo '}
# {'id': '4', 'name': ' salim', 'age': ' 28', 'city ': ' Torino'}
# {'id': '5', 'name': ' Michale', 'age': ' 45', 'city ': ' Perugia'}
# {'id': '6', 'name': ' Dilva', 'age': ' 56', 'city ': ' Modena'}

# %%
import csv

with open("my_data.csv") as f:
    reader = csv.DictReader(f) # trasforma in un dictionary
    for row in reader:
        print(row["id"], row["age"])# qui posso stampare solo alcune colonne (row)
# Out:
# 1  24
# 2  25
# 3  26
# 4  28
# 5  45
# 6  56

# %% [markdown]
# # tkinter

# %%
import tkinter as tk
