# %%
def calculate_area(a, b):
    return a * b

a = 10
b = 5

print(f"The area is {calculate_area(a, b)}")
# Out:
# The area is 50

# %%
name = "Alessio"

def introduce(name, age=25):
    return f"Hi my name is {name} and I am {age}"

print (introduce(name))
# Out:
# Hi my name is Alessio and I am 25

# %%
range[8]
def first_last (range):
    return
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 range[8]
#       2 def first_last (range):
#       3     return
#
# TypeError: type 'range' is not subscriptable

# %%
lista = range(0, 8)

def first_last(lista):
    return lista[0], lista[-1]

print(first_last(lista))
# Out:
# (0, 7)

# %%
import math as math

# %%
e = 16 
math.sqrt(e)
# Out:
# 4.0

# %%
import datetime as datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 2, 18, 22, 26, 1, 382145)

# %%
import datetime

d = datetime.datetime.now()
formatted = d.strftime("%d/%m/%y %H:%M")

print(formatted)
# Out:
# 18/02/26 22:29

# %%
# !pip install requests
requests.get()
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 get_ipython().system('pip install requests')
# ----> 2 requests.get()
#
# NameError: name 'requests' is not defined

# %%
import requests as rq

# %%
response = rq.get("https://google.com")

print (response)
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="it"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="592l1L95l7LKad2-3BwLTg">(function(){var _g={kEI:\'rDGWadyEJ-OlhbIPi47UkAQ\',kEXPI:\'0,1304203,3030760,344796,270475,5262487,15,36811391,25228681,152387,57121,8037,39775,75318,23263,114370,38788,14749,15974,2662,31976,19845,25296,21043,20678,11883,655,15524,15900,9996,15501,1383,4,1514,3355,197,5813,2,3418,787,8,1786,16,9132,5159,2,898,2207,5089,19,3007,24,772,12798,19570,4255,1034,4303,845,2047,1,1,9,14,1549,3,5941,2757,4,12115,3078,4,2184,12,3,43,241,297,5,1113,389,4,2647,5,5568,298,6256,2997,1275,7,2840,2,3859,8510,2,5724,9,602,1649,4,794,2591,2780,4,4339,1,2,803,3,1359,3,4910,70,10,215,441,158,2,1645,191,4,1928,4,1634,544,4,1567,114,862,59,1398,187,251,1854,5,259,5,197,2366,19,1540,4,2364,2363,5,3926,
# ...

# %%
response.statuscode
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 response.statuscode
#
# AttributeError: 'Response' object has no attribute 'statuscode'
