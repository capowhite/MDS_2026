# %%
str1 = " ciao come va tutto bene ?"
str2 = " si va tutto bene ma mi sono fale "
str3 = str1 + str2
str(str1[1:10:2])
# Out:
# 'ca oe'

# %%
i = "ciao"
print ('f"ciao, {i}')
# Out:
# f"ciao, {i}

# %%
my_list = [ 1, 2,3,4,5,"phyton", "ciao"]
my_list[3]
my_list.append(4)
my_list
my_list.remove(4)
my_list
my_list.pop(3)
my_list
# Out:
# [1, 2, 3, 'phyton', 'ciao', 4]

# %%
my_tuple = [ 1,2,3,4,5, "ciao", "tavolo"]
my_tuple[3]
# Out:
# 4

# %%
my_tuple.apped(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 my_tuple.apped(1)
#
# AttributeError: 'list' object has no attribute 'apped'

# %%
my_dict = {"nome": "Alessio", "cognome":"Capobianco", "Age":23}

# %%
my_dict["nome"]
# Out:
# 'Alessio'

# %%
my_dict=({"ciao":2})

# %%
my_dict["citta"] = 2

# %%
my_dict
# Out:
# {'nome': 'Alessio', 'cognome': 'Capobianco', 'Age': 23, 'citta': 2}

# %%
my_dict["esame"]="italianno"

# %%
my_dict
# Out:
# {'nome': 'Alessio',
#  'cognome': 'Capobianco',
#  'Age': 23,
#  'citta': 2,
#  'esame': 'italianno'}

# %%
my_dict["esame"]
# Out:
# 'italianno'

# %%
my_set = {1,2,3,4,5,6,7}
my_set.add(8)
my_set
my_set.add(4)
my_set
my_set.remove(1)
my_set
# Out:
# {2, 3, 4, 5, 6, 7, 8}

# %%
def calcolatrice ():
    num1 = float(input("insert a first number"))
    opertatore = str(input("insert a command"))
    num2 = float(input("insert a second number"))
    if opertatore == "+":
        risultato = num1 + num2
    elif opertatore == "-":
        risultato = num1 - num2 
    elif opertatore == "/":
        risultato = num1 / num2
    print(f"il risultato e' {risultato}")

# %%
calcolatrice ()
# Out:
# insert a first number 1
# insert a command -
# insert a second number 1
# il risultato e' 0.0
