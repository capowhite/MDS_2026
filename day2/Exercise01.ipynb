# %%
if 10>50:
    print("Ten is greater then five")
else:
    print("Today is a sunny day")

print ("today is a good day")
# Out:
# Today is a sunny day
# today is a good day

# %%
def sum (a,b):
    result = a+b # you cannot use number + letter , they both have to be the same 
    return result # we return the result variable 
    """ prova di fare un dockstring per vedere se funzioa, si funziona """

# %%
sum (10,25)
# Out:
# 250

# %%
sum ("mike", "eliza")
# Out:
# 'mikeeliza'

# %%
sum ("mike","Ciao")
# Out:
# 'mikeCiao'

# %%
age = 30 
age2 = 2
Age = 3

# %%
age
# Out:
# 30

# %%
Age
# Out:
# 3

# %%
building1 = "Church"

# %%
building1_name = "Church name" #snacke syntacs
building1Name = "church name " #camel syntacs
building1_hight = 100
building2_name = "Stadium Name"
building2_hight = 200
building3_name = "Igloo"
building3_hight = 400

# %%
building1
# Out:
# 'Church'

# %%
building1_name
# Out:
# 'Church name'

# %%
building1_hight
# Out:
# 100

# %%
print ( building3_hight) 
building3_hight
# Out:
# 400
# 400

# %%
age = 40.5 # is a float , because it has the decimal

# %%
student_name = "Maria"

# %%
maria = 10 
student = maria 
student
# Out:
# 10

# %%
maria 
maria 
maria
# Out:
# 10

# %%
print (maria)
print (maria)
# Out:
# 10
# 10

# %%
type ( student_name)
# Out:
# str

# %%
type (maria)
# Out:
# int

# %%
type(age)
# Out:
# float

# %%
alessio = False  #True and False must be in capital letter

# %%
type(alessio)
# Out:
# bool

# %% [raw]
# type(3>5)

# %%
d = str(alessio)

# %%
type (d)
# Out:
# str

# %%
d
# Out:
# 'False'

# %%
s = "20"

# %%
s+s
# Out:
# '2020'

# %%
int(s)+int(s)
# Out:
# 40

# %%
a = 10 
b = True 
c = "Julie"
d = 3.5

# %%
data1 = 1
value2 = 2
this_is_a_string = 3 
number_of_students_123 = 4

# %%
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 10.0

# %%
int(d)
# Out:
# 3

# %%
str(d)
# Out:
# '3.5'

# %%
float(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 float(c)
#
# ValueError: could not convert string to float: 'Julie'

# %%
max_distance = 3
temperature = 4.5
greet_int = "ciao"
is_raining = False 
value_1 
total_amount 
calc_num
data_entry
a = 42
float(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 5
#       3 greet_int = "ciao"
#       4 is_raining = False
# ----> 5 value_1
#       6 total_amount
#       7 calc_num
#
# NameError: name 'value_1' is not defined

# %%
max_distance = 3
temperature = 4.5
greet_int = "ciao"
is_raining = False 
value_1 =0
total_amount =0
calc_num = 0
data_entry = 1
a = 42
float(a)
b=3.14159
int(b)
c = 99.99
c1 = "99.99"
str(c)
float(c1)

# %%
type(max_distance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 type(max_distance)
#
# NameError: name 'max_distance' is not defined
